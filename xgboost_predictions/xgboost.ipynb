# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../atp_transformed/2000-2024 players_3.csv", low_memory=False) # We take the preprocessed dataset

# Quick inspection
print(df.shape)
df.head()
# Out:
# (1282807, 132)
#   tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0  1969-6818  St. Petersburg    Clay       64.0             A   1969-03-17
# 1  1969-2047    Jacksonville    Clay       32.0             A   1969-04-02
# 2  1970-2047    Jacksonville    Clay       32.0             A   1970-03-25
# 3   1971-583      Manchester   Grass      128.0             A   1971-05-31
# 4  1971-9341        Brisbane   Grass       64.0             A   1971-12-06
#
#    match_num    score  best_of tourney_round  ...  \
# 0        262  6-3 6-1        3           R64  ...
# 1        274  8-6 6-2        3           R32  ...
# 2        274  6-3 6-4        3           R32  ...
# 3        247  7-5 6-4        3           R64  ...
# 4        241  6-4 6-0        3           R64  ...
#
#    median_diff_rolling_mean_10 total_diff_rolling_mean_10  \
# 0                          NaN                        NaN
# 1                         -1.0                   5.000000
# ...

# %%
# We want to predict the highest possible ELO 

# Add ELO max
elo_max_df  = df.groupby('player_id')['elo'].max().reset_index()    # We add a column 'elo max' this is the highest achived elo rank for each player
elo_max_df.rename(columns={'elo': 'elo_max'}, inplace=True)  # The current elo column is replaced by the max elo column 

# Merge elo_max into the main dataframe
df = df.merge(elo_max_df, on='player_id', how='left')      # We merge the max elo column into the df


df['target'] = df['elo_max']    # We define our target: The highest possible elo


features = [      # The features are all player based features
    'player_age', # The current age of the player
    'days_of_experience', # The amount of days since the player had his/her first tournament
    'months_of_experience', # The amount of months since the player had his/her first tournament
    'years_of_experience',  # The amount of years since the player had his/her first tournament
    'player_rank',            # The current rank of this player (1 is current best player)
    'player_rank_points',     # The total amount of ranking points this player has scored (accumulation of points)
    'set_dominance_rolling_mean_10', # Rolling median over the last 10 set_dominance rows of the player. Set_dominance: Amount of sets won/ total sets played (per record/game)
    'tb_dominance_rolling_mean_10', # Rolling median over the last 10 tb_dominance rows of the player. Tb_dominance: Amount of tie break sets won/ total tie break sets played (per record/game)
    'mean_numb_rolling_mean_10', # Average of the last 10 number of games the winner won per round in the match (mean_numb = (6 + 7 + 6) / 3 = 6.33)
    'mean_diff_rolling_mean_10', # Average per-set game dominance (outscored his opponent per game) measures how decisively a player outplays opponents, across the last 10 matches.
    'mean_tb_numb_rolling_mean_10',  # Average number of tie-break points the player wins per tie-break, averaged over their previous 10 matches.
    'mean_tb_diff_rolling_mean_10', # Average per-tie-break set game dominance (outscored his opponent per game) measures how decisively a player outplays opponents, across the last 10 tie-break sets and smoothed across recent matches.
    'draw_size_rolling_med_10', # Rolling median over the last 10 total number of players in a tournament this player played.
    'highest_finish_position_rolling_med_10' # The player’s typical best tournament result over their last 10 tournaments, where lower values indicate deeper runs.
]

for f in features:
    df[f] = df.groupby('player_id')[f].shift(1) # Shifts the column down by one row within each group. This prevents data leakage

# Don't fill with mean, it produces worst results
df = df.dropna(subset=features + ['target'])     # Drop all columns from the dataframe except features and target

# %%
df.__len__() # Number of records in the df
# Out:
# 1093666

# %%
# One-hot encode tourney_level and drop one level as baseline
df = pd.get_dummies(df, columns=['tourney_level'], drop_first=True)  
features += [c for c in df.columns if c.startswith('tourney_level_')]  # Add encoded tourney_level columns to feature list

X = df[features].copy()  # Create feature matrix using selected features
y = df['target']  # Define target variable for modeling

# %%
# Define x/y train/test
df['tourney_date'] = pd.to_datetime(df['tourney_date'])  # Convert tournament date to datetime for time-based splitting
train = df[df['tourney_date'] < '2020-01-01']  # Use matches before 2020 as training data
test = df[df['tourney_date'] >= '2020-01-01']  # Use matches from 2020 onward as test data
# Time-based split: Mimics real-world prediction (no future data leaks into training). Often better for tournaments or time-series data.

X_train = train[features].fillna(train[features].median())  
y_train = train['target'] 
X_test = test[features].fillna(train[features].median())  
y_test = test['target'] 

dtrain = xgb.DMatrix(X_train, label=y_train)  
dtest  = xgb.DMatrix(X_test, label=y_test)  

params = {  # Define XGBoost hyperparameters
    "objective": "reg:squarederror",  # Use squared error loss for regression... ELO is a continuous variable, so regression with squared error (MSE) is appropriate.
    "learning_rate": 0.03,  # Control contribution of each tree... Low learning rate ensures gradual updates, preventing overfitting on 1.2M records. Slower learning allows the model to capture subtle patterns in player performance.
    "max_depth": 6,  # Controls tree complexity... Depth 6 balances learning non-linear interactions (like age × experience or rolling dominance metrics) without overfitting.
    "subsample": 0.8,  # Sample fraction of rows for each tree... Randomly samples 80% of rows per tree, improving generalization and speeding up training.
    "colsample_bytree": 0.8,  # Sample fraction of features for each tree... Randomly samples 80% of features per tree. Avoids over-reliance on a few correlated features (like: rolling averages of dominance).
    "seed": 42  # Ensure reproducible results
}

model = xgb.train(  # Train the XGBoost model
    params,
    dtrain,
    num_boost_round=1000,  # Maximum number of boosting iterations... Using a large num_boost_round combined with early stopping ensures the model has enough capacity without overfitting.
    evals=[(dtest, "eval")],  # Evaluate performance on test set
    early_stopping_rounds=50,  # Stop training if no improvement for 50 rounds... Prevents overfitting: Once the model stops improving on the validation/test set, we stop adding trees.
    verbose_eval=True  # Print evaluation metrics during training
)

y_pred = model.predict(dtest)
# Out:
# [0]	eval-rmse:273.83743
# [1]	eval-rmse:268.11900
# [2]	eval-rmse:262.81314
# [3]	eval-rmse:257.47353
# [4]	eval-rmse:252.26469
# [5]	eval-rmse:247.24055
# [6]	eval-rmse:242.71599
# [7]	eval-rmse:238.15155
# [8]	eval-rmse:233.64334
# [9]	eval-rmse:229.26328
# [10]	eval-rmse:225.22307
# [11]	eval-rmse:221.17661
# [12]	eval-rmse:219.89550
# [13]	eval-rmse:216.28509
# [14]	eval-rmse:212.71014
# [15]	eval-rmse:209.17812
# [16]	eval-rmse:205.72018
# [17]	eval-rmse:202.51524
# [18]	eval-rmse:199.30748
# [19]	eval-rmse:196.21222
# [20]	eval-rmse:193.25093
# [21]	eval-rmse:190.60162
# [22]	eval-rmse:187.88565
# [23]	eval-rmse:185.49169
# [24]	eval-rmse:182.94062
# [25]	eval-rmse:181.67503
# [26]	eval-rmse:179.39154
# [27]	eval-rmse:177.24367
# [28]	eval-rmse:175.03044
# [29]	eval-rmse:172.93277
# [30]	eval-rmse:171.00424
# [31]	eval-rmse:169.03209
# [32]	eval-rmse:167.12460
# [33]	eval-rmse:165.28492
# [34]	eval-rmse:163.65799
# [35]	eval-rmse:161.96955
# [36]	eval-rmse:160.44110
# ...

# %%
mse = mean_squared_error(y_test, y_pred)  # Compute mean squared error between predictions and true values
rmse = np.sqrt(mse)  # Convert MSE to root mean squared error for interpretability
r2 = r2_score(y_test, y_pred)  # Compute R-squared to measure explained variance

print(f"RMSE: {rmse:.2f}")  
print(f"R2: {r2:.3f}")
# Out:
# RMSE: 127.50
# R2: 0.789

# %%
importance_dict = model.get_score(importance_type='weight')  # Get feature importance, options: 'weight', 'gain', 'cover'

feat_imp = pd.DataFrame({  # Convert importance dictionary to a DataFrame
    'feature': list(importance_dict.keys()),  
    'importance': list(importance_dict.values())  
}).sort_values(by='importance', ascending=False)  # Sort features by descending importance

print(feat_imp)
# Out:
#                                    feature  importance
# 0                               player_age      2889.0
# 1                       days_of_experience      2586.0
# 5                       player_rank_points      1624.0
# 4                              player_rank      1602.0
# 2                     months_of_experience       786.0
# 9                mean_diff_rolling_mean_10       749.0
# 13  highest_finish_position_rolling_med_10       408.0
# 8                mean_numb_rolling_mean_10       405.0
# 6            set_dominance_rolling_mean_10       391.0
# 12                draw_size_rolling_med_10       358.0
# 10            mean_tb_numb_rolling_mean_10       247.0
# 19                         tourney_level_S       143.0
# 7             tb_dominance_rolling_mean_10       105.0
# 3                      years_of_experience        99.0
# 15                         tourney_level_C        78.0
# 14                         tourney_level_A        61.0
# ...

# %%
# Example: early-career snapshot of a new player
new_player = pd.DataFrame({
    'player_age': [20],
    'days_of_experience': [150],
    'months_of_experience': [5],
    'years_of_experience': [0.4],
    'player_rank': [300],
    'player_rank_points': [120], # Important that a player has accumulated rank_points in order to be ranked
    'set_dominance_rolling_mean_10': [0.6],
    'tb_dominance_rolling_mean_10': [0.5],
    'mean_numb_rolling_mean_10': [6.0],
    'mean_diff_rolling_mean_10': [0.5],
    'mean_tb_numb_rolling_mean_10': [3.0],
    'mean_tb_diff_rolling_mean_10': [0.2],
    'draw_size_rolling_med_10': [32],
    'highest_finish_position_rolling_med_10': [16],
    # Dummy variables for tourney_level if used in training
    'tourney_level_A': [0],
    'tourney_level_D': [0],
    'tourney_level_F': [0],
    'tourney_level_G': [0],
    'tourney_level_M': [1]
})

# Fill any missing features with 0
for col in X_train.columns:
    if col not in new_player.columns:
        new_player[col] = 0

# Ensure column order matches training data
new_player = new_player[X_train.columns]

# Convert to DMatrix for Booster prediction
dnew = xgb.DMatrix(new_player)

# Predict highest Elo
pred_elo_max = model.predict(dnew)
print("Predicted highest Elo:", pred_elo_max[0])
# Out:
# Predicted highest Elo: 2034.0474

# %%
# Save the model

model.save_model("xgb_elo_model.json")

# %%
# Load the model

model = xgb.Booster()
model.load_model("xgb_elo_model.json")

# %%
import pandas as pd

def top_players_by_year(df, year, top_n=20):
    """
    Show highest-ranked players for a given year (no duplicates).
    Ranking is based on best (lowest) player_rank achieved that year.
    """

    # Ensure datetime
    df = df.copy()
    df['tourney_date'] = pd.to_datetime(df['tourney_date'])

    # Filter year
    year_df = df[df['tourney_date'].dt.year == year]

    if year_df.empty:
        print(f"No data available for year {year}")
        return

    # Keep best rank per player for that year
    best_rank_year = (
        year_df
        .groupby('player_id', as_index=False)
        .agg({
            'player_name': 'first',        # player name
            'player_rank': 'min',          # best rank
            'player_rank_points': 'max',   # peak points that year
            'elo': 'max'                   # peak elo that year
        })
        .sort_values('player_rank')
        .head(top_n)
    )

    print("=" * 60)
    print(f"TOP {top_n} HIGHEST-RANKED PLAYERS IN {year}")
    print("=" * 60)

    display(best_rank_year.reset_index(drop=True))


# -------------------------
# USAGE
# -------------------------
top_players_by_year(
    df=df,
    year=2023,   # <-- CHANGE YEAR HERE
    top_n=50
)
# Out:
# ...
# TOP 50 HIGHEST-RANKED PLAYERS IN 2023
# ...
#     player_id                  player_name  player_rank  player_rank_points  \
# 0      207989               Carlos Alcaraz          1.0              9815.0
# 1      104925               Novak Djokovic          1.0             11795.0
# 2      106421              Daniil Medvedev          2.0              7490.0
# 3      104745                 Rafael Nadal          2.0              6020.0
# 4      100644             Alexander Zverev          3.0              7075.0
# 5      126774           Stefanos Tsitsipas          3.0              5940.0
# 6      134770                  Casper Ruud          3.0              5820.0
# 7      208029                  Holger Rune          4.0              4825.0
# 8      206173                Jannik Sinner          4.0              6490.0
# 9      126094                Andrey Rublev          5.0              4935.0
# 10     126203                 Taylor Fritz          5.0              3865.0
# ...

# %%
def inspect_player_elo(player_id, df, model, features, train_medians):
    """
    Inspect true and predicted max ELO for a given player_id
    """

    player_df = df[df['player_id'] == player_id].copy()

    if player_df.empty:
        print(f"No data found for player_id: {player_id}")
        return

    # Sort chronologically
    player_df = player_df.sort_values("tourney_date")

    # True ELO values
    elo_history = player_df[['tourney_date', 'elo']]

    true_elo_max = player_df['elo'].max()

    # Use the LAST available row for prediction (most realistic)
    latest_row = player_df.iloc[-1:]

    X_player = latest_row[features].fillna(train_medians)
    dplayer = xgb.DMatrix(X_player)

    predicted_elo_max = model.predict(dplayer)[0]

    print("=" * 60)
    print(f"PLAYER ID: {player_id}")
    print("=" * 60)

    print("ELO HISTORY:")
    display(elo_history)

    print("TRUE MAX ELO ACHIEVED:")
    print(f"{true_elo_max:.2f}")

    print("PREDICTED MAX ELO (Model):")
    print(f"{predicted_elo_max:.2f}")

    print("DIFFERENCE (Predicted - True):")
    print(f"{predicted_elo_max - true_elo_max:+.2f}")

    print("=" * 60)


# ----------------------------------------
# PRECOMPUTE TRAIN MEDIANS (DO THIS ONCE)
# ----------------------------------------
train_medians = train[features].median()

# ----------------------------------------
# USAGE
# ----------------------------------------
inspect_player_elo(
    player_id=104354,      # <-- CHANGE PLAYER ID HERE 
    df=df,
    model=model,
    features=features,
    train_medians=train_medians
)
# Out:
# ...
# PLAYER ID: 104354
# ...
# ELO HISTORY:
#        tourney_date          elo
# 360731   2002-05-06  1481.276123
# 360732   2002-05-13  1468.535232
# 360741   2002-06-24  1461.354680
# 360742   2002-08-19  1477.868974
# 360743   2002-08-19  1493.848940
# ...             ...          ...
# 361315   2015-08-31  1799.083263
# 361316   2015-09-07  1772.018517
# 361317   2016-03-14  1788.909687
# 361318   2016-07-04  1782.999763
# 361319   2016-07-04          NaN
#
# [552 rows x 2 columns]
# TRUE MAX ELO ACHIEVED:
# 1917.46
# PREDICTED MAX ELO (Model):
# 1810.03
# DIFFERENCE (Predicted - True):
# -107.43
# ...

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

def inspect_player_elo(player_id, df, model, features, train_medians):
    """
    Inspect achieved yearly ELO and predicted max ELO per year for a given player
    Marks highest achieved and predicted ELO on the graph
    """

    player_df = df[df['player_id'] == player_id].copy()

    if player_df.empty:
        print(f"No data found for player_id: {player_id}")
        return

    # Sort chronologically
    player_df = player_df.sort_values("tourney_date")

    # Player name
    player_name = player_df['player_name'].iloc[0]

    # Add year
    player_df['year'] = player_df['tourney_date'].dt.year

    # ----------------------------
    # ONE ROW PER YEAR (YEAR-END)
    # ----------------------------
    yearly_df = (
        player_df
        .groupby('year')
        .last()
        .reset_index()
    )

    # ----------------------------
    # PREDICT MAX ELO PER YEAR
    # ----------------------------
    X_yearly = yearly_df[features].fillna(train_medians)
    d_yearly = xgb.DMatrix(X_yearly)
    yearly_df['predicted_max_elo'] = model.predict(d_yearly)

    # ----------------------------
    # FIND PEAKS
    # ----------------------------
    achieved_peak_idx = yearly_df['elo'].idxmax()
    predicted_peak_idx = yearly_df['predicted_max_elo'].idxmax()

    achieved_peak_year = yearly_df.loc[achieved_peak_idx, 'year']
    achieved_peak_elo = yearly_df.loc[achieved_peak_idx, 'elo']

    predicted_peak_year = yearly_df.loc[predicted_peak_idx, 'year']
    predicted_peak_elo = yearly_df.loc[predicted_peak_idx, 'predicted_max_elo']

    # ----------------------------
    # PRINT SUMMARY
    # ----------------------------
    print("=" * 70)
    print(f"PLAYER: {player_id} — {player_name}")
    print("=" * 70)
    print(f"HIGHEST ACHIEVED ELO: {achieved_peak_elo:.2f} ({achieved_peak_year})")
    print(f"HIGHEST PREDICTED MAX ELO: {predicted_peak_elo:.2f} ({predicted_peak_year})")
    print("=" * 70)

    # ----------------------------
    # PLOT
    # ----------------------------
    plt.figure(figsize=(12, 6))

    # Achieved ELO
    plt.plot(
        yearly_df['year'],
        yearly_df['elo'],
        marker='o',
        linewidth=2,
        label='Achieved ELO'
    )

    # Predicted max ELO
    plt.plot(
        yearly_df['year'],
        yearly_df['predicted_max_elo'],
        marker='s',
        linestyle='--',
        linewidth=2,
        label='Predicted Max ELO'
    )

    # Highlight highest achieved ELO
    plt.scatter(
        achieved_peak_year,
        achieved_peak_elo,
        s=120,
        color='blue',
        edgecolor='black',
        zorder=5,
        label=f'Highest Achieved ELO: {achieved_peak_elo:.0f} ({achieved_peak_year})'
    )

    # Highlight highest predicted max ELO
    plt.scatter(
        predicted_peak_year,
        predicted_peak_elo,
        s=120,
        color='red',
        edgecolor='black',
        zorder=5,
        label=f'Highest Predicted Max ELO: {predicted_peak_elo:.0f} ({predicted_peak_year})'
    )

    plt.title(
        f"Achieved ELO vs Predicted Max ELO by Year — {player_id} ({player_name})"
    )
    plt.xlabel("Year")
    plt.ylabel("ELO")
    plt.xticks(yearly_df['year'])
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()


inspect_player_elo(
player_id=104925,      # <-- CHANGE PLAYER ID HERE     
df=df,
model=model,
features=features,
train_medians=train_medians)
# Out:
# ...
# PLAYER: 104925 — Novak Djokovic
# ...
# HIGHEST ACHIEVED ELO: 2906.96 (2015)
# HIGHEST PREDICTED MAX ELO: 2875.64 (2012)
# ...

# %%
def inspect_player_elo_multi_snapshot(
    player_id,
    df,
    model,
    features,
    train_medians,
    snapshot_years=(3, 5, 10)
):
    """
    Creates 3 graphs comparing achieved ELO vs predicted max ELO
    using player snapshots from the 3rd, 5th, and 10th active years
    """

    player_df = df[df['player_id'] == player_id].copy()

    if player_df.empty:
        print(f"No data found for player_id: {player_id}")
        return

    # Sort chronologically
    player_df = player_df.sort_values("tourney_date")
    player_name = player_df['player_name'].iloc[0]

    # Add year
    player_df['year'] = player_df['tourney_date'].dt.year

    # One row per year (year-end)
    yearly_df = (
        player_df
        .groupby('year')
        .last()
        .reset_index()
        .sort_values('year')
        .reset_index(drop=True)
    )

    total_years = len(yearly_df)

    # Prepare achieved ELO (same for all plots)
    achieved_years = yearly_df['year']
    achieved_elo = yearly_df['elo']

    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

    for ax, snap in zip(axes, snapshot_years):

        if snap > total_years:
            ax.set_title(f"{snap}th Year Snapshot\n(Not Available)")
            ax.axis("off")
            continue

        # Snapshot row (freeze player at this career year)
        snapshot_row = yearly_df.iloc[snap - 1]

        # Repeat snapshot features across all future years
        X_snapshot = (
            pd.DataFrame(
                np.tile(snapshot_row[features].values, (total_years, 1)),
                columns=features
            )
            .fillna(train_medians)
        )

        d_snapshot = xgb.DMatrix(X_snapshot)
        predicted_elo = model.predict(d_snapshot)

        # Plot achieved ELO
        ax.plot(
            achieved_years,
            achieved_elo,
            marker='o',
            linewidth=2,
            label='Achieved ELO'
        )

        # Plot predicted ELO from snapshot
        ax.plot(
            achieved_years,
            predicted_elo,
            linestyle='--',
            linewidth=2,
            label=f'Predicted (Year {snap} Snapshot)'
        )

        # Mark snapshot year
        ax.axvline(
            snapshot_row['year'],
            color='gray',
            linestyle=':',
            alpha=0.7,
            label=f'Snapshot Year ({snapshot_row["year"]})'
        )

        ax.set_title(f"{snap}th Active Year Prediction")
        ax.set_xlabel("Year")
        ax.grid(alpha=0.3)

    axes[0].set_ylabel("ELO")
    axes[0].legend()

    fig.suptitle(
        f"Achieved ELO vs Predicted Max ELO Snapshots — {player_id} ({player_name})",
        fontsize=14
    )

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

inspect_player_elo_multi_snapshot(
    player_id=104925,
    df=df,
    model=model,
    features=features,
    train_medians=train_medians
)
# Out:
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\2598061397.py:61: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\2598061397.py:61: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# ...

# %%
import os

# Create prediction graphs of players using different carreer snapshots
def inspect_player_elo_multi_snapshot(
    player_id,
    df,
    model,
    features,
    train_medians,
    elo_min,
    elo_max,
    snapshot_years=(3, 5, 10),
    save_path=None
):
    """
    Creates 3 graphs comparing achieved ELO vs predicted max ELO
    using player snapshots from the 3rd, 5th, and 10th active years
    """

    player_df = df[df['player_id'] == player_id].copy()

    if player_df.empty:
        print(f"No data found for player_id: {player_id}")
        return

    # Sort chronologically
    player_df = player_df.sort_values("tourney_date")
    player_name = player_df['player_name'].iloc[0]

    # Add year
    player_df['year'] = player_df['tourney_date'].dt.year

    # One row per year (year-end)
    yearly_df = (
        player_df
        .groupby('year')
        .last()
        .reset_index()
        .sort_values('year')
        .reset_index(drop=True)
    )

    total_years = len(yearly_df)
    years = yearly_df['year'].values

    fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

    for ax, snap in zip(axes, snapshot_years):

        ax.set_ylim(elo_min, elo_max)
        if snap > total_years:
            ax.set_title(f"{snap}th Year Snapshot\n(Not Available)")
            ax.axis("off")
            continue

        # Snapshot row
        snapshot_row = yearly_df.iloc[snap - 1]
        snapshot_year = snapshot_row['year']

        # Freeze features at snapshot
        X_snapshot = (
            pd.DataFrame(
                np.tile(snapshot_row[features].values, (total_years, 1)),
                columns=features
            )
            .fillna(train_medians)
        )

        d_snapshot = xgb.DMatrix(X_snapshot)
        predicted_elo = model.predict(d_snapshot)

        # Achieved ELO
        ax.plot(
            years,
            yearly_df['elo'],
            marker='o',
            linewidth=2,
            label='Achieved ELO'
        )

        # Predicted ELO
        ax.plot(
            years,
            predicted_elo,
            linestyle='--',
            linewidth=2,
            label=f'Prediction based on year (n)'
        )

        # Snapshot year marker (RED + legend)
        ax.axvline(
            snapshot_year,
            color='red',
            linestyle=':',
            linewidth=2,
            alpha=0.8,
            label=f'Prediction year (n)'
        )

        # ---- X-axis ticks: ensure snapshot year is visible and non-overlapping ----
        max_ticks = 6

        # Start with evenly spaced ticks (including first & last)
        base_ticks = np.linspace(years[0], years[-1], max_ticks, dtype=int)
        ticks = set(base_ticks)

        # Always include snapshot year
        ticks.add(snapshot_year)

        # Protect critical ticks
        protected = {years[0], years[-1], snapshot_year}

        # If too many ticks, remove the closest non-protected one
        while len(ticks) > max_ticks:
            removable = sorted(ticks - protected)
            if not removable:
                break
            # Remove tick closest to snapshot year
            remove_tick = min(removable, key=lambda x: abs(x - snapshot_year))
            ticks.remove(remove_tick)

        ticks = sorted(ticks)
        ax.set_xticks(ticks)
        ax.set_xlabel("Year")
        ax.set_title(f"{snap}th year")
        ax.grid(alpha=0.3)

    axes[0].set_ylabel("ELO")

    # Global legend (top-left of figure)
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(
        handles,
        labels,
        loc='upper left',
        bbox_to_anchor=(0.01, 0.99)
    )

    fig.suptitle(
        f"Achieved ELO vs Predicted Max ELO — {player_id} ({player_name})",
        fontsize=14
    )

    plt.tight_layout(rect=[0, 0, 1, 0.93])
    if save_path:
        os.makedirs("Test_results", exist_ok=True)
        full_path = os.path.join("Test_results", save_path)
        plt.savefig(full_path, dpi=300, bbox_inches='tight')
    plt.show()


inspect_player_elo_multi_snapshot(    
player_id= 104925, #207989,   #104925,
df=df,    
model=model,
features=features,
train_medians=train_medians,
elo_min=1500,
elo_max=3000
)
# Out:
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\1706294895.py:66: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\1706294895.py:66: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# ...

# %%
# ---- Compute active years per player ----
player_years = (
    df.assign(year=df['tourney_date'].dt.year)
      .groupby('player_id')['year']
      .nunique()
      .reset_index(name='n_years')
)

# Keep only players with more than 5 years
eligible_players = player_years[player_years['n_years'] > 5]['player_id']


# ---- Compute peak ELO per player ----
player_peak_elo = (
    df[df['player_id'].isin(eligible_players)]
    .groupby('player_id')['elo']
    .max()
    .reset_index(name='peak_elo')
    .sort_values('peak_elo', ascending=False)
    .reset_index(drop=True)
)

# ---- Top 10 ----
top_players = player_peak_elo.head(10)['player_id'].tolist()

# ---- True middle 10 ----
mid_start = len(player_peak_elo) // 2 - 5
average_players = (
    player_peak_elo
    .iloc[mid_start:mid_start + 10]['player_id']
    .tolist()
)


# Make predictions based on these players

groups = {
    "top": top_players,
    "average": average_players
}

for group_name, player_ids in groups.items():

    os.makedirs(f"Test_results/{group_name}", exist_ok=True)

    for pid in player_ids:
        print(f"Processing {group_name.upper()} player: {pid}")

        inspect_player_elo_multi_snapshot(
            player_id=pid,
            df=df,
            model=model,
            features=features,
            train_medians=train_medians,
            elo_min=1500,
            elo_max=3000,
            save_path=f"{group_name}/player_{pid}_elo_snapshots.png"
        )
# Out:
# Processing TOP player: 104925
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\1706294895.py:66: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# C:\Users\jesse\AppData\Local\Temp\ipykernel_7944\1706294895.py:66: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(train_medians)
# ...

# %%
# ===== USER INPUTS =====
player_id_input = 104925
year_input = 2004


# ===== 1. FILTER TO PLAYER & YEAR =====
player_year_df = df[
    (df["player_id"] == player_id_input) &
    (df["tourney_date"].dt.year == year_input)
].sort_values("tourney_date")

if player_year_df.empty:
    raise ValueError("No records found for this player and year.")


# ===== 2. OLDEST RECORD IN THAT YEAR =====
snapshot = player_year_df.iloc[0]


# ===== 3. BUILD FEATURE ROW (NON–tourney_level FEATURES) =====
new_player = pd.DataFrame({
    "player_age": [snapshot["player_age"]],
    "days_of_experience": [snapshot["days_of_experience"]],
    "months_of_experience": [snapshot["months_of_experience"]],
    "years_of_experience": [snapshot["years_of_experience"]],
    "player_rank": [snapshot["player_rank"]],
    "player_rank_points": [snapshot["player_rank_points"]],
    "set_dominance_rolling_mean_10": [snapshot["set_dominance_rolling_mean_10"]],
    "tb_dominance_rolling_mean_10": [snapshot["tb_dominance_rolling_mean_10"]],
    "mean_numb_rolling_mean_10": [snapshot["mean_numb_rolling_mean_10"]],
    "mean_diff_rolling_mean_10": [snapshot["mean_diff_rolling_mean_10"]],
    "mean_tb_numb_rolling_mean_10": [snapshot["mean_tb_numb_rolling_mean_10"]],
    "mean_tb_diff_rolling_mean_10": [snapshot["mean_tb_diff_rolling_mean_10"]],
    "draw_size_rolling_med_10": [snapshot["draw_size_rolling_med_10"]],
    "highest_finish_position_rolling_med_10": [snapshot["highest_finish_position_rolling_med_10"]],
})


# ===== 4. ADD / FILL MISSING COLUMNS (incl. tourney_level dummies) =====
for col in X_train.columns:
    if col not in new_player.columns:
        new_player[col] = 0

# Ensure column order matches training data
new_player = new_player[X_train.columns]


# ===== 5. PREDICT elo_max =====
dnew = xgb.DMatrix(new_player)
pred_elo_max = model.predict(dnew)[0]


# ===== 6. TRUE elo_max FROM DATA =====
true_elo_max = snapshot["elo_max"]
 

# ===== 7. OUTPUT =====
print(f"Player ID: {player_id_input}")
print(f"Year: {year_input}")
print(f"Snapshot date: {snapshot['tourney_date'].date()}")
print(f"Predicted elo_max: {pred_elo_max:.2f}")
print(f"True elo_max: {true_elo_max:.2f}")
print(f"Prediction error: {pred_elo_max - true_elo_max:.2f}")
# Out:
# Player ID: 104925
# Year: 2004
# Snapshot date: 2004-02-02
# Predicted elo_max: 2496.21
# True elo_max: 2938.31
# Prediction error: -442.10
